# %%
# все библиотеки

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from itertools import product
# %matplotlib inline
import seaborn
plt.style.use('ggplot')

# %%
# считывание данных

df_pion = pd.read_csv('data/v1_pion_train.csv')
df_kaon = pd.read_csv('data/v1_kaon_train.csv')
df_electron = pd.read_csv('data/v1_electron_train.csv')
df_ghost = pd.read_csv('data/v1_ghost_train.csv')
df_muon = pd.read_csv('data/v1_muon_train.csv')
df_proton = pd.read_csv('data/v1_proton_train.csv')

# %% [markdown]
# ### данные

# %%
df_pion.head()
# Out:
#       TrackPt        TrackP  NumLongTracks  MCParticleType  RichDLLbt  \
# 0  292.449890   5383.890137           95.0            -211    -4.8921
# 1  537.121704   5875.910156           23.0            -211   -24.2808
# 2  996.601135   5114.390137           61.0             211   -30.7045
# 3  514.304382  20254.830078           72.0             211    -1.6131
# 4  303.679565   3026.860107           43.0             211    -0.4927
#
#    RichDLLk  RichDLLmu  RichDLLp   RichDLLe  TrackEta
# 0   -4.8921     1.1894   -4.8921  -8.547900  3.605282
# 1  -24.2808    -9.2196  -24.2808 -30.771500  3.083443
# 2  -30.7045   -27.5772  -30.7045 -53.311001  2.318979
# 3   -1.2550    -2.0739   -1.6131  -6.002100  4.366319
# 4   -0.4927     0.4731   -0.4927 -17.817699  2.989929

# %%
df_pion.describe()
# Out:
#             TrackPt        TrackP  NumLongTracks  MCParticleType  \
# count  1.000006e+06  1.000006e+06   1.000006e+06    1.000006e+06
# mean   6.108592e+02  1.165775e+04   5.000846e+01    4.051176e-01
# std    6.110336e+02  1.537453e+04   2.296046e+01    2.109997e+02
# min    5.804594e+00  1.120040e+03   1.000000e+00   -2.110000e+02
# 25%    2.732105e+02  3.932927e+03   3.300000e+01   -2.110000e+02
# 50%    4.434661e+02  6.965105e+03   4.700000e+01    2.110000e+02
# 75%    7.377449e+02  1.340857e+04   6.400000e+01    2.110000e+02
# max    6.542564e+04  1.067609e+06   1.830000e+02    2.110000e+02
#
#           RichDLLbt      RichDLLk     RichDLLmu      RichDLLp      RichDLLe  \
# count  1.000006e+06  1.000006e+06  1.000006e+06  1.000006e+06  1.000006e+06
# mean  -4.058832e+01 -4.134828e+01 -3.363571e+01 -4.080971e+01 -4.464395e+01
# std    1.563932e+02  1.563977e+02  1.569423e+02  1.563940e+02  1.559057e+02
# ...

# %%
df_kaon.head()
# Out:
#        TrackPt        TrackP  NumLongTracks  MCParticleType  RichDLLbt  \
# 0   733.720825   7811.620117           40.0             321   5.395000
# 1   766.389587  13805.900391           29.0             321  32.001301
# 2   454.289093   4635.049805           32.0             321  17.493500
# 3  1054.564331   4333.899902           26.0             321  19.676600
# 4  1975.175537  24745.910156           57.0            -321  20.518400
#
#     RichDLLk  RichDLLmu   RichDLLp  RichDLLe  TrackEta
# 0   5.395000    -2.7621   5.395000   -6.4719  3.056173
# 1  48.601002    -4.4894  32.001301  -11.0133  3.583537
# 2  17.493500   -12.2938  17.493500   -7.7980  3.013405
# 3  19.676600    -7.5441  19.676600  -11.6452  2.091345
# 4  52.582600     0.0612  10.397500    0.0172  3.219554

# %%
df_kaon.describe()
# Out:
#              TrackPt        TrackP  NumLongTracks  MCParticleType  \
# count  999993.000000  9.999930e+05  999993.000000   999993.000000
# mean      917.169911  1.720783e+04      49.570274        4.437214
# std       870.250223  2.147142e+04      23.126351      320.969491
# min        19.675070  1.143810e+03       1.000000     -321.000000
# 25%       406.408234  5.646150e+03      32.000000     -321.000000
# 50%       674.999756  1.041678e+04      46.000000      321.000000
# 75%      1129.237061  2.039669e+04      64.000000      321.000000
# max     80601.171875  1.063457e+06     183.000000      321.000000
#
#            RichDLLbt       RichDLLk      RichDLLmu       RichDLLp  \
# count  999993.000000  999993.000000  999993.000000  999993.000000
# mean       -4.132112       1.683412     -17.207840      -4.545270
# std       125.769343     126.901186     123.419692     125.708882
# min      -999.000000    -999.000000    -999.000000    -999.000000
# ...

# %%
df_electron.head()
# Out:
#        TrackPt         TrackP  NumLongTracks  MCParticleType   RichDLLbt  \
# 0  2900.960449  146387.968750           17.0              11  -26.357599
# 1  1039.614624   38299.628906           62.0              11   -9.234400
# 2   748.570251   35151.000000           38.0             -11    4.259600
# 3    80.008705    4731.169922           26.0             -11 -999.000000
# 4   999.364868   38570.808594           49.0              11  -20.354700
#
#    RichDLLk  RichDLLmu  RichDLLp  RichDLLe  TrackEta
# 0   -2.7567     0.0447  -13.6412    0.1041  4.614268
# 1   -0.8999     0.0833    0.2746    0.1979  4.299553
# 2   -3.3145     0.3723    5.8671    1.6676  4.542277
# 3 -999.0000  -999.0000 -999.0000 -999.0000  4.772868
# 4  -32.7187     0.2124  -24.8507   -0.7465  4.346110

# %%
df_electron.describe()
# Out:
#             TrackPt        TrackP  NumLongTracks  MCParticleType  \
# count  1.000004e+06  1.000004e+06   1.000004e+06    1.000004e+06
# mean   7.744103e+02  1.200671e+04   4.523818e+01   -3.286787e-02
# std    1.022024e+03  1.880961e+04   2.253575e+01    1.099996e+01
# min    6.317903e+00  1.163420e+03   1.000000e+00   -1.100000e+01
# 25%    2.031424e+02  3.426308e+03   2.800000e+01   -1.100000e+01
# 50%    4.200316e+02  6.069970e+03   4.200000e+01   -1.100000e+01
# 75%    9.365944e+02  1.257874e+04   5.900000e+01    1.100000e+01
# max    4.021005e+04  1.236918e+06   1.940000e+02    1.100000e+01
#
#           RichDLLbt      RichDLLk     RichDLLmu      RichDLLp      RichDLLe  \
# count  1.000004e+06  1.000004e+06  1.000004e+06  1.000004e+06  1.000004e+06
# mean  -6.927121e+01 -7.014971e+01 -6.069618e+01 -6.984179e+01 -4.223394e+01
# std    2.448307e+02  2.447469e+02  2.465360e+02  2.447843e+02  2.525838e+02
# ...

# %%
df_ghost.head()
# Out:
#       TrackPt        TrackP  NumLongTracks  MCParticleType   RichDLLbt  \
# 0  494.463684   1923.849976           12.0               0    0.000000
# 1   81.083633   4240.009766           63.0               0 -999.000000
# 2  450.273376  14234.519531           39.0               0   15.703200
# 3  563.783081   3682.260010           26.0               0   18.708099
# 4  117.248886   2202.000000           45.0               0    0.000000
#
#      RichDLLk  RichDLLmu    RichDLLp    RichDLLe  TrackEta
# 0    0.000000     0.0000    0.000000  -35.542198  2.034818
# 1 -999.000000  -999.0000 -999.000000 -999.000000  4.649895
# 2   16.970400    -0.8900   15.703200   -5.172300  4.146467
# 3   18.708099    -1.5353   18.708099   -5.129300  2.563847
# 4    0.000000     3.3365    0.000000   -9.898700  3.625260

# %%
df_ghost.describe()
# Out:
#              TrackPt        TrackP  NumLongTracks  MCParticleType  \
# count  999995.000000  9.999950e+05  999995.000000        999995.0
# mean      385.562737  8.576308e+03      58.258465             0.0
# std      2120.557016  3.075479e+04      24.609492             0.0
# min         0.451171  1.118740e+03       1.000000             0.0
# 25%       113.097980  2.821880e+03      40.000000             0.0
# 50%       205.899185  4.601630e+03      55.000000             0.0
# 75%       404.583603  8.632430e+03      74.000000             0.0
# max    633395.437500  4.969893e+06     194.000000             0.0
#
#            RichDLLbt       RichDLLk      RichDLLmu       RichDLLp  \
# count  999995.000000  999995.000000  999995.000000  999995.000000
# mean     -156.868826    -157.161512    -157.718459    -156.940455
# std       362.826010     362.703642     362.357847     362.797323
# min      -999.000000    -999.000000    -999.000000    -999.000000
# ...

# %%
df_muon.head()
# Out:
#        TrackPt        TrackP  NumLongTracks  MCParticleType   RichDLLbt  \
# 0  1994.030762  25978.289062           47.0              13  -71.401497
# 1  1627.580444   6140.810059           66.0             -13  -23.658199
# 2  2714.667725  18381.529297           72.0             -13    7.284800
# 3   847.640381  12456.349609           60.0             -13    3.355200
# 4   140.604111   5683.930176           37.0             -13 -999.000000
#
#      RichDLLk   RichDLLmu    RichDLLp    RichDLLe  TrackEta
# 0  -87.541901   -3.880900  -79.582802   -8.966200  3.258774
# 1  -23.658199   32.602001  -23.658199  -17.655899  2.002966
# 2  -12.056900    0.593900   13.134600    2.585600  2.600326
# 3   -7.069100    0.723500    3.355200    0.127200  3.379517
# 4 -999.000000 -999.000000 -999.000000 -999.000000  4.392444

# %%
df_muon.describe()
# Out:
#             TrackPt        TrackP  NumLongTracks  MCParticleType  \
# count  1.000001e+06  1.000001e+06   1.000001e+06    1.000001e+06
# mean   1.977057e+03  3.019452e+04   4.155917e+01    5.368995e-03
# std    3.133910e+03  4.595246e+04   2.179848e+01    1.300001e+01
# min    8.310864e+00  1.109380e+03   1.000000e+00   -1.300000e+01
# 25%    6.058935e+02  6.458260e+03   2.500000e+01   -1.300000e+01
# 50%    1.391642e+03  1.544247e+04   3.800000e+01    1.300000e+01
# 75%    2.587355e+03  3.588513e+04   5.400000e+01    1.300000e+01
# max    5.782048e+05  4.750951e+06   1.820000e+02    1.300000e+01
#
#           RichDLLbt      RichDLLk     RichDLLmu      RichDLLp      RichDLLe  \
# count  1.000001e+06  1.000001e+06  1.000001e+06  1.000001e+06  1.000001e+06
# mean  -4.028382e+01 -3.955991e+01 -9.066890e+00 -4.207504e+01 -1.911727e+01
# std    1.173354e+02  1.179659e+02  1.182111e+02  1.177225e+02  1.168489e+02
# ...

# %%
df_proton.head()
# Out:
#        TrackPt        TrackP  NumLongTracks  MCParticleType  RichDLLbt  \
# 0   463.939606   3072.429932           58.0           -2212     2.5472
# 1   681.318787   1956.859985           63.0           -2212     0.0000
# 2   428.073242   2778.239990            6.0           -2212     3.9483
# 3  2067.380615  37160.468750           45.0            2212    32.2906
# 4   392.244202   3534.719971           12.0           -2212     8.2376
#
#    RichDLLk  RichDLLmu   RichDLLp   RichDLLe  TrackEta
# 0    2.5472    -5.6044   2.547200 -18.342199  2.577867
# 1    0.0000     0.0000   0.000000 -34.756199  1.716429
# 2    3.9483    -9.3194   3.948300 -21.707399  2.557437
# 3   -3.0960    -0.1078  50.999802  -0.176800  3.581336
# 4    8.2376    -6.6311   8.237600 -16.298700  2.888559

# %%
df_proton.describe()
# Out:
#              TrackPt        TrackP  NumLongTracks  MCParticleType  \
# count  999994.000000  9.999940e+05  999994.000000   999994.000000
# mean      951.632676  1.767020e+04      50.565653       81.127799
# std       811.404172  2.220218e+04      23.010854     2210.512874
# min         8.959981  1.164830e+03       1.000000    -2212.000000
# 25%       434.631180  5.529433e+03      34.000000    -2212.000000
# 50%       730.671417  1.045704e+04      48.000000     2212.000000
# 75%      1217.480927  2.109436e+04      65.000000     2212.000000
# max     37309.593750  1.347937e+06     194.000000     2212.000000
#
#            RichDLLbt       RichDLLk      RichDLLmu       RichDLLp  \
# count  999994.000000  999994.000000  999994.000000  999994.000000
# mean       -0.555735      -3.916865     -16.145458       1.405363
# std       121.914981     121.295212     119.363720     122.294681
# min      -999.000000    -999.000000    -999.000000    -999.000000
# ...

# %% [markdown]
# ##  Общее распределение данных для предсказываемых переменных

# %%
x_cols = ['TrackP', 'TrackEta', 'NumLongTracks']
y_cols = ['RichDLLbt', 'RichDLLk', 'RichDLLmu', 'RichDLLp', 'RichDLLe']

# %%
for col in y_cols:
    bins = np.linspace(
            start=min(df_pion[col].min(), df_kaon[col].min(), df_muon[col].min(), df_proton[col].min(),
                      df_electron[col].min(), df_ghost[col].min()), 
            stop =max(df_pion[col].max(), df_kaon[col].max(), df_muon[col].min(), df_proton[col].min(),
                      df_electron[col].max(), df_ghost[col].max()), 
            num=601
        )
    plt.subplots(figsize=(20, 10))
    plt.hist(df_pion[col], bins=bins, label='pions', alpha=0.6)
    plt.hist(df_kaon[col], bins=bins, label='kaons', alpha=0.6)
    plt.hist(df_muon[col], bins=bins, label='muons', alpha=0.6)
    plt.hist(df_electron[col], bins=bins, label='electrons', alpha=0.6)
    plt.hist(df_proton[col], bins=bins, label='protons', alpha=0.6)
    plt.hist(df_ghost[col], bins=bins, label='ghosts', alpha=0.6)
    plt.yscale('log')
    plt.grid()
    plt.xlim(left=-1100) 
    plt.legend(loc='best')
    plt.xlabel('RichDLLk')

# %% [markdown]
# ## отфильтруем данные

# %%
not_outlier_pion = df_pion.RichDLLk > -500
not_outlier_kaon = df_kaon.RichDLLk > -500
not_outlier_muon = df_muon.RichDLLk > -500
not_outlier_proton = df_proton.RichDLLk > -500
not_outlier_electron = df_electron.RichDLLk > -500
not_outlier_ghost = df_ghost.RichDLLk > -500

for col in y_cols:
    bins = np.linspace(
            start=min(df_pion[col][not_outlier_pion].min(), df_kaon[col][not_outlier_kaon].min(),
                      df_muon[col][not_outlier_muon].min(), df_proton[col][not_outlier_proton].min(),
                      df_electron[col].min(), df_ghost[col].min()), 
            stop =max(df_pion[col][not_outlier_pion].max(), df_kaon[col][not_outlier_kaon].max(),
                      df_muon[col][not_outlier_muon].min(), df_proton[col][not_outlier_proton].min(),
                      df_electron[col][not_outlier_electron].max(), df_ghost[col][not_outlier_ghost].max()), 
            num=601
        )
    plt.subplots(figsize=(20, 10))
    plt.hist(df_pion[col][not_outlier_pion], bins=bins, label='pions', alpha=0.6)
    plt.hist(df_kaon[col][not_outlier_kaon], bins=bins, label='kaons', alpha=0.6)
    plt.hist(df_muon[col][not_outlier_muon], bins=bins, label='muons', alpha=0.6)
    plt.hist(df_electron[col][not_outlier_electron], bins=bins, label='electrons', alpha=0.6)
    plt.hist(df_proton[col][not_outlier_proton], bins=bins, label='protons', alpha=0.6)
    plt.hist(df_ghost[col][not_outlier_ghost], bins=bins, label='ghosts', alpha=0.6)
    plt.yscale('log')
    plt.xlim(left=-400) 
    plt.grid()
    plt.legend(loc='best')
    plt.xlabel('RichDLLk')

# %%
for col in y_cols:
    fig, (ax_pion, ax_kaon) = plt.subplots(
                                        nrows=1,
                                        ncols=2,
                                        figsize=(15, 6)
                                    )

    _, bins_x, bins_y, img_pion = \
        ax_pion.hist2d(
                x=df_pion.TrackEta,
                y=df_pion[col],
                bins=(100, bins),
                cmap='seismic',
                norm=colors.LogNorm()
            )
    _, _, _, img_kaon = \
        ax_kaon.hist2d(
                x=df_kaon.TrackEta,
                y=df_kaon[col],
                bins=(bins_x, bins_y),
                cmap='seismic',
                norm=colors.LogNorm()
            )

    plt.colorbar(img_pion, ax=ax_pion)
    plt.colorbar(img_kaon, ax=ax_kaon)
    ax_pion.set_xlabel('Eta')
    ax_kaon.set_xlabel('Eta')
    ax_pion.set_ylabel(col)
    ax_kaon.set_ylabel(col)
    ax_pion.set_title('Pions')
    ax_kaon.set_title('Kaons')
    fig.tight_layout()

# %%
def hist2d(data,col1,col2,bins_x, bins_y):
    
    fig, axes = plt.subplots(
                                    nrows= 2,
                                    ncols= int(len(data)/2),
                                    figsize=(15, 6)
                                )
    
    for i, p in enumerate(data):
        _, _, _, img = \
            axes[i % 2][i//2].hist2d(
                x=data[p][col1],
                y=data[p][col2],
                bins=(bins_x, bins_y),
                cmap='inferno',
                norm=colors.LogNorm()
            )
        axes[i % 2][i//2].set_xlabel(col1)
        axes[i % 2][i//2].set_ylabel(col2)
        axes[i % 2][i//2].set_title(p)
        plt.colorbar(img, ax=axes[i % 2][i//2])
        
#    fig.suptitle(f'{x}x{y}')
    fig.tight_layout();

# %%
for x, y in product(x_cols,y_cols):
    
    hist2d({p:data[p][masks[p]] for p in data},x,y,101,101)
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-533a25e4c2ca> in <module>()
#       1 for x, y in product(x_cols,y_cols):
#       2
# ----> 3     hist2d({p:data[p][masks[p]] for p in data},x,y,101,101)
#       4     print()
#
# NameError: name 'data' is not defined

# %% [markdown]
# ## The simplest model possible

# %%
class Model:
    def train(self, X, Y):
        self.means = {}
        self.stds = {}
        for col in Y.columns:
            self.means[col] = np.mean(Y[col])
            self.stds [col] = np.std (Y[col])

    def predict(self, X):
        prediction = pd.DataFrame()
        for col in self.means.keys():
            prediction[col] = np.random.normal(
                                loc=self.means[col],
                                scale=self.stds[col],
                                size=len(X)
                            )
        return prediction

# %%
from sklearn.model_selection import KFold
from scipy.stats import ks_2samp

# %%
def score_func(sample1, sample2):
    score = 0
  
    # at first, let's ignore X
    for col in y_cols:
        score += ks_2samp(sample1[col], sample2[col])[0]
    return score

# %%
kf = KFold(n_splits=5)

model_scores = []
best_scores  = []

for train_index, test_index in kf.split(df_pion[x_cols]):
    X_train = df_pion[x_cols].iloc[train_index]
    Y_train = df_pion[y_cols].iloc[train_index]
    X_test  = df_pion[x_cols].iloc[test_index ]
    Y_test  = df_pion[y_cols].iloc[test_index ]
  
    model = Model()
    model.train(X_train[not_outlier_pion[train_index]], Y_train[not_outlier_pion[train_index]])
    Y_pred = model.predict(X_test)
  
    model_scores.append(score_func(Y_test, Y_pred))
    best_scores .append(score_func(Y_test, Y_train))

# %%
bins = np.linspace(
            start=min(model_scores + best_scores), 
            stop =max(model_scores + best_scores), 
            num=201
        )

plt.subplots(figsize=(20, 10))
plt.grid()
plt.hist(model_scores, bins=bins, label='model')
plt.hist(best_scores , bins=bins, label='best possible', alpha=0.6)
plt.legend(loc='best')
plt.xlabel('KS Scores');

# %%
for col in Y_pred.columns:
    plt.subplots(figsize=(20, 10))
    plt.grid()
    _, bins, _ = plt.hist(Y_test[col], bins=100 , label='test'      )
    _, _   , _ = plt.hist(Y_pred[col], bins=bins, label='prediction', alpha=0.7)
    plt.legend(loc='best')
    plt.xlim(left=-1100)
    plt.xlabel(col)
    plt.show();

# %%
kf = KFold(n_splits=5)

model_scores = []
best_scores  = []
non_outlier = df_kaon.RichDLLk > -500
for train_index, test_index in kf.split(df_kaon[x_cols]):
    X_train = df_kaon[x_cols].iloc[train_index]
    Y_train = df_kaon[y_cols].iloc[train_index]
    X_test  = df_kaon[x_cols].iloc[test_index ]
    Y_test  = df_kaon[y_cols].iloc[test_index ]
  
    model = Model()
    model.train(X_train[not_outlier_kaon[train_index]], Y_train[not_outlier_kaon[train_index]])
    Y_pred = model.predict(X_test)
  
    model_scores.append(score_func(Y_test, Y_pred))
    best_scores .append(score_func(Y_test, Y_train))

# %%
bins = np.linspace(
            start=min(model_scores + best_scores), 
            stop =max(model_scores + best_scores), 
            num=201
        )

plt.subplots(figsize=(20, 10))
plt.grid()
plt.hist(model_scores, bins=bins, label='model')
plt.hist(best_scores , bins=bins, label='best possible', alpha=0.6)
plt.legend(loc='best')
plt.xlabel('KS Scores');

# %%
for col in Y_pred.columns:
    plt.subplots(figsize=(20, 10))
    plt.grid()
    _, bins, _ = plt.hist(Y_test[col], bins=100 , label='test'      )
    _, _   , _ = plt.hist(Y_pred[col], bins=bins, label='prediction', alpha=0.7)
    plt.legend(loc='best')
    plt.xlim(left=-1100)
    plt.xlabel(col)
    plt.show();
